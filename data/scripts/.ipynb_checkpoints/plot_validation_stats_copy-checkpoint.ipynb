# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from os.path import join
import pickle
import pprint

# %%
stats_dir = '/home/suvansh/levine/continualrl/data/scripts/validation_stats/'
exp_name = '09-08-tool-dqn-dynamic-static-resetfree'
stats_pkl_file = 'stats_2019_09_09_07_30_02.pkl'

stats_path = join(stats_dir, exp_name, stats_pkl_file)
stats = pickle.load(open(stats_path, 'rb'))

# %%
# leave lists blank to choose all
desired_metrics = ['proportion_solved']
desired_variants = []

# %%
# looping over variants (hyperparam settings)
xs = {}
ys = {}
for variant_hash, stat in stats['hash_to_stats'].items():
    xs[variant_hash] = {}
    ys[variant_hash] = {}
    # looping over every 10 epochs (frequency at which validation was performed)
    for t in list(zip(*[stat_seed.items() for stat_seed in stat])):
        # looping over the collected performance metrics
        for key in t[0][1].keys():
            if key not in xs[variant_hash]:
                xs[variant_hash][key] = []
            if key not in ys[variant_hash]:
                ys[variant_hash][key] = []
            avg_perf = sum(seed_t[1][key] for seed_t in t) / len(t)
            xs[variant_hash][key].append(t[0][0])
            ys[variant_hash][key].append(avg_perf)

# %%
ys[2571292948508563899].keys()
# ys.keys()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-e621f44875d0> in <module>
# ----> 1 ys[2571292948508563899].keys()
#       2 # ys.keys()
#
# KeyError: 2571292948508563899

# %%
# plotting
for variant_hash, metrics in xs.items():
    if desired_variants and variant_hash not in desired_variants:
        continue
    for metric, x in metrics.items():
        if desired_metrics and metric not in desired_metrics:
            continue
        y = ys[variant_hash][metric]
        # plot y vs x with title that includes the hash and metric name
        plt.plot(x, y)
        plt.title('%s: %s' % (metric, variant_hash))
        print(variant_hash)
        plt.show()
# Out:
# -2524204692237930733
# 1288031418284737114
# 3424450127311493454
# 4338727861457256958
# 404550957431671881
# 8500140810890688044
# 1515124490824098806
# -2894523413361309617
# -8216049082249091112
# -7425702185078620994
# -2749661300551470975
# -7011716295875298771
# 7992044018771431859
# 5635676407357600790
# -5415011284032529243
# 7806254652925064790
# 3484072126708214947
# -4086449047478647123
# 3210635007973754520
# 5357592426655397677

# %%
# single figure plotting
for variant_hash, metrics in xs.items():
    if desired_variants and variant_hash not in desired_variants:
        continue
    for metric, x in metrics.items():
        if desired_metrics and metric not in desired_metrics:
            continue
        y = ys[variant_hash][metric]
        # plot y vs x with title that includes the hash and metric name
        plt.plot(x, y, label='variant %s' % variant_hash)
        plt.title('%s: %s' % (metric, variant_hash))
        print(variant_hash)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
# Out:
# -2524204692237930733
# 1288031418284737114
# 3424450127311493454
# 4338727861457256958
# 404550957431671881
# 8500140810890688044
# 1515124490824098806
# -2894523413361309617
# -8216049082249091112
# -7425702185078620994
# -2749661300551470975
# -7011716295875298771
# 7992044018771431859
# 5635676407357600790
# -5415011284032529243
# 7806254652925064790
# 3484072126708214947
# -4086449047478647123
# 3210635007973754520
# 5357592426655397677

# %%
for vhash in desired_variants:
    print(vhash)
    pprint.pprint(stats['hash_to_variant'][vhash]['env_kwargs'])
    print('-----------------------------------------------')
# Out:
# 198929321776461040
# {'agent_start_pos': None,
#  'default_lifespan': 200,
#  'end_on_task_completion': False,
#  'fixed_expected_resources': False,
#  'fixed_reset': False,
#  'fully_observed': False,
#  'gen_resources': True,
#  'grid_size': 8,
#  'health_cap': 1000,
#  'init_resources': {'metal': 2, 'wood': 2},
#  'make_rtype': 'sparse',
#  'only_partial_obs': True,
#  'replenish_empty_resources': [],
#  'resource_prob': {'metal': 0.02, 'wood': 0.02},
#  'resource_prob_decay': {'metal': 1e-06, 'wood': 1e-06},
#  'resource_prob_min': {'metal': 0.01, 'wood': 0.01},
#  'task': 'make_lifelong axe',
#  'time_horizon': 0}
# -----------------------------------------------
# -161893430528816860
# {'agent_start_pos': None,
#  'default_lifespan': 200,
#  'end_on_task_completion': False,
#  'fixed_expected_resources': False,
#  'fixed_reset': False,
#  'fully_observed': False,
#  'gen_resources': True,
#  'grid_size': 8,
#  'health_cap': 1000,
#  'init_resources': {'metal': 2, 'wood': 2},
#  'make_rtype': 'sparse',
#  'only_partial_obs': True,
#  'replenish_empty_resources': ['metal', 'wood'],
#  'resource_prob': {'metal': 0.02, 'wood': 0.02},
#  'resource_prob_decay': {'metal': 1e-06, 'wood': 1e-06},
#  'resource_prob_min': {'metal': 0.01, 'wood': 0.01},
#  'task': 'make_lifelong axe',
#  'time_horizon': 0}
# -----------------------------------------------
# 9101241210143366543
# {'agent_start_pos': None,
#  'default_lifespan': 200,
#  'end_on_task_completion': False,
#  'fixed_expected_resources': False,
#  'fixed_reset': False,
#  'fully_observed': False,
#  'gen_resources': True,
#  'grid_size': 8,
#  'health_cap': 1000,
#  'init_resources': {'metal': 1, 'wood': 1},
#  'make_rtype': 'sparse',
#  'only_partial_obs': True,
#  'replenish_empty_resources': [],
#  'resource_prob': {'metal': 0.08, 'wood': 0.08},
#  'resource_prob_decay': {'metal': 1e-05, 'wood': 1e-05},
#  'resource_prob_min': {'metal': 0.01, 'wood': 0.01},
#  'task': 'make_lifelong axe',
#  'time_horizon': 0}
# -----------------------------------------------
# 6904784455701835292
# {'agent_start_pos': None,
#  'default_lifespan': 200,
#  'end_on_task_completion': False,
#  'fixed_expected_resources': False,
#  'fixed_reset': False,
#  'fully_observed': False,
#  'gen_resources': True,
#  'grid_size': 8,
#  'health_cap': 1000,
#  'init_resources': {'metal': 1, 'wood': 1},
#  'make_rtype': 'sparse',
#  'only_partial_obs': True,
#  'replenish_empty_resources': ['metal', 'wood'],
#  'resource_prob': {'metal': 0.05, 'wood': 0.05},
#  'resource_prob_decay': {'metal': 1e-06, 'wood': 1e-06},
#  'resource_prob_min': {'metal': 0.01, 'wood': 0.01},
#  'task': 'make_lifelong axe',
#  'time_horizon': 0}
# -----------------------------------------------
# 8484378055337889386
# {'agent_start_pos': None,
#  'default_lifespan': 200,
#  'end_on_task_completion': False,
#  'fixed_expected_resources': False,
#  'fixed_reset': False,
#  'fully_observed': False,
#  'gen_resources': True,
#  'grid_size': 8,
#  'health_cap': 1000,
#  'init_resources': {'metal': 1, 'wood': 1},
#  'make_rtype': 'sparse',
#  'only_partial_obs': True,
#  'replenish_empty_resources': ['metal', 'wood'],
#  'resource_prob': {'metal': 0.05, 'wood': 0.05},
#  'resource_prob_decay': {'metal': 1e-05, 'wood': 1e-05},
#  'resource_prob_min': {'metal': 0.01, 'wood': 0.01},
#  'task': 'make_lifelong axe',
#  'time_horizon': 0}
# -----------------------------------------------
