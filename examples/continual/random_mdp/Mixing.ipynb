# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import pickle

# %%
data = pickle.load(open('mixing_2020_02_05_15_28_16.pkl', 'rb'))
times = data['times']

# %%
start_idx = 15
# plt.plot(np.linspace(0, 1, times.shape[1])[start_idx:], np.log(times.mean(axis=0)[start_idx:]))
plt.plot(np.linspace(0, 1, times.shape[1])[start_idx:], times.mean(axis=0)[start_idx:])
plt.title('Random Markov Chain Mixing Time with Dynamism (S=1000)')
plt.xlabel('Beta (Increasing Dynamism)')
plt.ylabel('Mixing Time (Timesteps)')
plt.savefig('mixing_pic.png')
plt.show()
# NOTE:
variant = dict(
    n_iters=1,
    s=1000,
    num_support=0,
    betas=np.linspace(0, 1, 501, endpoint=True).tolist(),
    sparse=True,
    sparse_dist=3,
    deterministic=False,
    eps=1e-8
)

# %%
data['variant']
# Out:
# {'n_iters': 1,
#  's': 1000,
#  'num_support': 0,
#  'betas': [0.0,
#   0.002,
#   0.004,
#   0.006,
#   0.008,
#   0.01,
#   0.012,
#   0.014,
#   0.016,
#   0.018000000000000002,
#   0.02,
#   0.022,
#   0.024,
#   0.026000000000000002,
#   0.028,
#   0.03,
#   0.032,
#   0.034,
#   0.036000000000000004,
#   0.038,
#   0.04,
#   0.042,
#   0.044,
#   0.046,
#   0.048,
#   0.05,
#   0.052000000000000005,
#   0.054,
#   0.056,
#   0.058,
#   0.06,
#   0.062,
#   0.064,
#   0.066,
#   0.068,
#   0.07,
#   0.07200000000000001,
#   0.074,
#   0.076,
#   0.078,
#   0.08,
#   0.082,
#   0.084,
#   0.08600000000000001,
#   0.088,
#   0.09,
#   0.092,
#   0.094,
#   0.096,
#   0.098,
#   0.1,
#   0.10200000000000001,
#   0.10400000000000001,
#   0.106,
#   0.108,
#   0.11,
#   0.112,
#   0.114,
#   0.116,
#   0.11800000000000001,
#   0.12,
#   0.122,
#   0.124,
#   0.126,
#   0.128,
#   0.13,
#   0.132,
#   0.134,
#   0.136,
#   0.138,
#   0.14,
#   0.14200000000000002,
# ...

# %%
pickle.dump(data, open('mixing_final.pkl', 'wb'))
